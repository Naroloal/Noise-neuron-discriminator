# %%
from scipy import stats
# %matplotlib widget
from scipy.io import loadmat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import matplotlib.cm as cm
from Funciones_auxiliares import Mat_to_dataframe,see_teams,get_cluster_indexs,plot_branch,plot_teams,find_mix
from scipy import cluster
import scipy as sp
import math

# %%
plt.close('all')
plt.clf()
plt.close()
data = pd.read_pickle('Datos/PCCIBNMZc')
Maindf =  data[data.PatientExperiment.str.contains('HEC030|HEC031|HEC032')]
Second_df = data[data.PatientExperiment.str.contains('HEC018|HEC020|HEC022|HEC017')]
Third_df = data[data.PatientExperiment.str.contains('HEC006|HEC008|HEC010|HEC016')]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
data['Mean'] = data.Bulk.apply(lambda row: np.mean(row,axis = 0))
data['Mean'] = (data['Mean'] - data.Mean.apply(lambda row:np.mean(row)))/data.Mean.apply(lambda row:np.std(row))

# %%
Noise = Maindf[Maindf.bNoise == 1]
Noise.reset_index(inplace = True)
Neuron = Maindf[Maindf.bNoise == 0]
Neuron.reset_index(inplace = True)
Mu = Maindf[Maindf.bNoise == 2]
Mu.reset_index(inplace = True)

# %%
Mean_noise = pd.DataFrame(np.array(Noise.Mean.to_list()))
Corr = Mean_noise.corr()
# Out:
#             0          1          2          3          4          5   \
# 0    -2.239974  -2.068948  -1.844098  -1.830718  -2.391444  -3.611093
# 1    38.343076 -15.189842 -62.013614 -69.028388 -31.880209  24.281181
# 2   -11.733314 -15.052504 -17.735799 -19.382960 -18.478390 -16.427819
# 3    -6.595303  -6.733900  -6.796459  -6.778703  -6.710624  -6.749331
# 4    -5.088311  -5.803955  -6.582385  -7.224863  -7.687744  -8.069161
# ..         ...        ...        ...        ...        ...        ...
# 160   3.225279   0.756947  -1.684788  -4.106842  -6.530879  -8.997534
# 161  50.426961  50.790394  49.696397  46.935242  42.559806  36.963160
# 162  17.922231  20.454883  21.735784  22.153431  22.089509  21.377794
# 163   5.713231   5.125030   5.170626   5.805344   6.584495   6.976977
# 164   4.689531   5.092053   5.765267   5.908372   5.063939   3.445538
#
#             6          7          8          9   ...         54         55  \
# ...

# %%
threshold2 = 0.1## For Pearson is defined as 1 - correlation

# %%
#linkage_p = cluster.hierarchy.linkage(Mean_Noise,method = 'complete',metric = 'correlation')
#linkage_p = cluster.hierarchy.linkage(P_Value_p,method = 'complete',metric = 'euclidean')
#Z_p = cluster.hierarchy.dendrogram(linkage_p,color_threshold = threshold2,leaf_font_size = 8)
fl = cluster.hierarchy.fcluster(linkage_p,threshold2,criterion = 'distance')

# %%
Noise['Team'] = 0
for i in range(1,max(fl)+1):
    tup = get_cluster_indexs(i,fl)
    Noise['Team'][tup] = i

# %%
Mix_teams = []
print('There are mix teams??')
for team in np.arange(1,max(fl)+1):
    spikes_shapes = get_cluster_indexs(team,fl)
    aux = list(df.bNoise[spikes_shapes])
    aux2 = []
    for element in aux:
          aux2.append(element)
    if  (aux2.count(1) !=0) and (aux2.count(0)!=0):
        print('Yes, team {} is a mix team'.format(team))
        Mix_teams.append(team)
# Out:
# There are mix teams??
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a29c1150efd6> in <module>
#       3 for team in np.arange(1,max(fl)+1):
#       4     spikes_shapes = get_cluster_indexs(team,fl)
# ----> 5     aux = list(df.bNoise[spikes_shapes])
#       6     aux2 = []
#       7     for element in aux:
#
# NameError: name 'df' is not defined

# %%
threshold = np.linspace(0,1,1000)
num_teams_correlated_per_threshold = []
for t in threshold:
    fl = cluster.hierarchy.fcluster(linkage_p,t,criterion = 'distance')
    Mix_teams = find_mix(df,fl)
    num_teams_correlated_per_threshold.append(len(Mix_teams))

# %%
Data = pd.DataFrame({'threshold': threshold, 'Num_mix_team':num_teams_correlated_per_threshold})

# %%
len(Mix_teams)
# Out:
# 41

# %%
Data.iplot(x = 'threshold',y = 'Num_mix_team',mode = 'markers + lines',xTitle='Threshold',yTitle = 'Num_mixed_teams',size=3)
# Out:
# <div>
#
#
#             <div id="ca538770-1fe2-4d42-ab78-b6b0eb3394f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ca538770-1fe2-4d42-ab78-b6b0eb3394f6")) {
#                     Plotly.newPlot(
#                         'ca538770-1fe2-4d42-ab78-b6b0eb3394f6',
# ...
